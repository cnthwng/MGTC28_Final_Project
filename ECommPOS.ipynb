# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
ecomm_pos = pd.read_csv('C:\\Users\\harry\\Documents\\MGTC28H3 F\\Code\\Group Project\\kenvue_data\\Total Ecomm POS (Factory $) - UTSC Lecture.csv', header=[0,1])

# %%
ecomm_pos.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Fiscal Week
#           Need State        Fiscal Year           1         2         3
# 0       Need State 1               2021     3684.75   3426.75   4221.75  \
# 1       Need State 1               2022     3441.75   3657.00   3806.25
# 2       Need State 1               2023     2901.75   2919.75   2760.75
# 3       Need State 2               2021    11283.00  12698.25  18210.00
# 4       Need State 2               2022     8566.50  11636.25   9718.50
#
#                                                      ...
#           4         5         6         7         8  ...       43       44
# 0   2959.50   3402.75   3440.25   2619.00   3240.75  ...  2651.25  2442.75  \
# 1   3765.75   3984.00   2999.25   3231.75   2896.50  ...  2754.00  2427.75
# 2   2525.25   3274.50   2631.00   2621.25   2297.25  ...     0.00     0.00
# 3  12725.25  19290.75  12869.25  14770.50  13758.00  ...  9129.75  7565.25
# ...

# %%
ecomm_pos.columns
# Out:
# MultiIndex([('Unnamed: 0_level_0',  'Need State'),
#             ('Unnamed: 1_level_0', 'Fiscal Year'),
#             (       'Fiscal Week',           '1'),
#             (       'Fiscal Week',           '2'),
#             (       'Fiscal Week',           '3'),
#             (       'Fiscal Week',           '4'),
#             (       'Fiscal Week',           '5'),
#             (       'Fiscal Week',           '6'),
#             (       'Fiscal Week',           '7'),
#             (       'Fiscal Week',           '8'),
#             (       'Fiscal Week',           '9'),
#             (       'Fiscal Week',          '10'),
#             (       'Fiscal Week',          '11'),
#             (       'Fiscal Week',          '12'),
#             (       'Fiscal Week',          '13'),
#             (       'Fiscal Week',          '14'),
#             (       'Fiscal Week',          '15'),
#             (       'Fiscal Week',          '16'),
# ...

# %%
ecomm_pos = ecomm_pos.set_index([('Unnamed: 0_level_0',  'Need State'), ('Unnamed: 1_level_0', 'Fiscal Year')])

# %%
ecomm_pos = ecomm_pos.T

# %%
ecomm_pos
# Out:
# ('Unnamed: 0_level_0', 'Need State')  Need State 1
# ('Unnamed: 1_level_0', 'Fiscal Year')         2021     2022     2023
# Fiscal Week 1                              3684.75  3441.75  2901.75  \
#             2                              3426.75  3657.00  2919.75
#             3                              4221.75  3806.25  2760.75
#             4                              2959.50  3765.75  2525.25
#             5                              3402.75  3984.00  3274.50
#             6                              3440.25  2999.25  2631.00
#             7                              2619.00  3231.75  2621.25
#             8                              3240.75  2896.50  2297.25
#             9                              3461.25  2938.50  2717.25
#             10                             3045.00  3370.50  3062.25
#             11                             3942.75  3465.00  2283.75
#             12                             4527.00  4341.00  3463.50
# ...

# %%
ecomm_pos = ecomm_pos.stack(0)

# %%
ecomm_pos
# Out:
# ('Unnamed: 1_level_0', 'Fiscal Year')                2021      2022     2023
#                (Unnamed: 0_level_0, Need State)
# Fiscal Week 1  Need State 1                       3684.75   3441.75  2901.75
#                Need State 2                      11283.00   8566.50  7915.50
#                Need State 3                      11958.75   8359.50  5179.50
#                Need State 4                      14755.50  11095.50  6963.00
#                Need State 5                        448.50    471.00  1221.00
# ...                                                   ...       ...      ...
#             52 Need State 2                       7518.00  14489.25     0.00
#                Need State 3                       6012.00   9322.50     0.00
#                Need State 4                       8635.50   6142.50     0.00
#                Need State 5                        382.50    795.75     0.00
#                Need State 6                       5531.25   5622.75     0.00
#
# ...

# %%
ecomm_pos = ecomm_pos.reset_index()

# %%
ecomm_pos
# Out:
# ('Unnamed: 1_level_0', 'Fiscal Year')      level_0 level_1
# 0                                      Fiscal Week       1  \
# 1                                      Fiscal Week       1
# 2                                      Fiscal Week       1
# 3                                      Fiscal Week       1
# 4                                      Fiscal Week       1
# ..                                             ...     ...
# 307                                    Fiscal Week      52
# 308                                    Fiscal Week      52
# 309                                    Fiscal Week      52
# 310                                    Fiscal Week      52
# 311                                    Fiscal Week      52
#
# ('Unnamed: 1_level_0', 'Fiscal Year') (Unnamed: 0_level_0, Need State)
# 0                                                         Need State 1  \
# 1                                                         Need State 2
# ...

# %%
# Let's rename the columns
ecomm_pos = ecomm_pos.rename_axis(None, axis=1)
ecomm_pos = ecomm_pos.rename(columns={ecomm_pos.columns[1]: "week", ecomm_pos.columns[2]: "Need State"})
ecomm_pos
# Out:
#          level_0 week    Need State      2021      2022     2023
# 0    Fiscal Week    1  Need State 1   3684.75   3441.75  2901.75
# 1    Fiscal Week    1  Need State 2  11283.00   8566.50  7915.50
# 2    Fiscal Week    1  Need State 3  11958.75   8359.50  5179.50
# 3    Fiscal Week    1  Need State 4  14755.50  11095.50  6963.00
# 4    Fiscal Week    1  Need State 5    448.50    471.00  1221.00
# ..           ...  ...           ...       ...       ...      ...
# 307  Fiscal Week   52  Need State 2   7518.00  14489.25     0.00
# 308  Fiscal Week   52  Need State 3   6012.00   9322.50     0.00
# 309  Fiscal Week   52  Need State 4   8635.50   6142.50     0.00
# 310  Fiscal Week   52  Need State 5    382.50    795.75     0.00
# 311  Fiscal Week   52  Need State 6   5531.25   5622.75     0.00
#
# [312 rows x 6 columns]

# %%
# Dataframes for each need state
ecomm_n1 = ecomm_pos[(ecomm_pos['Need State']=='Need State 1')]
ecomm_n2 = ecomm_pos[(ecomm_pos['Need State']=='Need State 2')]
ecomm_n3 = ecomm_pos[(ecomm_pos['Need State']=='Need State 3')]
ecomm_n4 = ecomm_pos[(ecomm_pos['Need State']=='Need State 4')]
ecomm_n5 = ecomm_pos[(ecomm_pos['Need State']=='Need State 5')]
ecomm_n1.head(10)
# Out:
#         level_0 week    Need State     2021     2022     2023
# 0   Fiscal Week    1  Need State 1  3684.75  3441.75  2901.75
# 6   Fiscal Week    2  Need State 1  3426.75  3657.00  2919.75
# 12  Fiscal Week    3  Need State 1  4221.75  3806.25  2760.75
# 18  Fiscal Week    4  Need State 1  2959.50  3765.75  2525.25
# 24  Fiscal Week    5  Need State 1  3402.75  3984.00  3274.50
# 30  Fiscal Week    6  Need State 1  3440.25  2999.25  2631.00
# 36  Fiscal Week    7  Need State 1  2619.00  3231.75  2621.25
# 42  Fiscal Week    8  Need State 1  3240.75  2896.50  2297.25
# 48  Fiscal Week    9  Need State 1  3461.25  2938.50  2717.25
# 54  Fiscal Week   10  Need State 1  3045.00  3370.50  3062.25

# %%
# Dataframes for each year
ec_2021 = ecomm_pos.iloc[0:, :-2]
ec_2022 = ecomm_pos.drop([2021, 2023], axis=1).iloc[0:, :]
ec_2023 = ecomm_pos.drop([2021, 2022], axis=1).iloc[0:, :]

ec_2021.head()
# Out:
#        level_0 week    Need State      2021
# 0  Fiscal Week    1  Need State 1   3684.75
# 1  Fiscal Week    1  Need State 2  11283.00
# 2  Fiscal Week    1  Need State 3  11958.75
# 3  Fiscal Week    1  Need State 4  14755.50
# 4  Fiscal Week    1  Need State 5    448.50

# %%
sns.set(font_scale=0.5)
sns.lineplot(data=ecomm_n1).set(title='Need State 1 ECommerce POS')
plt.show()
sns.set(font_scale=0.5)
sns.lineplot(data=ecomm_n2).set(title='Need State 2 ECommerce POS')
plt.show()
sns.lineplot(data=ecomm_n3).set(title='Need State 3 ECommerce POS')
plt.show()
sns.lineplot(data=ecomm_n4).set(title='Need State 4 ECommerce POS')
plt.show()
sns.lineplot(data=ecomm_n5).set(title='Need State 5 ECommerce POS')

#Question:
# How do I assign 'week' as the x axis instead of the index? 
# It shows an error everytime I do it by 'week'...

# %%
# EComm Graphs for 2021, 2022, 2023
sns.set(font_scale=0.5)
sns.lineplot(data=ec_2021, x="week", y=2021, hue="Need State").set(title='ECommerce POS 2021')
plt.show()
sns.lineplot(data=ec_2022, x="week", y=2022, hue="Need State").set(title='ECommerce POS 2022')
plt.show()
sns.lineplot(data=ec_2023, x="week", y=2023, hue="Need State").set(title='ECommerce POS 2023')
plt.show()
#sns.lineplot(data=ec_2021.T, x='week')

# %%
#y2021 = ecomm_pos[(ecomm_pos['Fiscal Year']=='2021')]
#y2022 = ecomm_pos[(ecomm_pos['Fiscal Year']=='2022')]
#y2023 = ecomm_pos[(ecomm_pos['Fiscal Year']=='2023')]

# %%
#y2022.head()

# %%
#for col in y2021.columns:
#    print(col)

# %%
# y2021 = y2021.pivot(index="Need State", columns="Fiscal Week", values="2021 Factory POS")
# y2021 = y2021[sorted(y2021.columns, key=lambda x: int(x))]

# df_2021.head

# %%
#y2021_n1 = y2021[(y2021['Need State']=='Need State 1')]
#y2021_n2 = y2021[(y2021['Need State']=='Need State 2')]
#y2021_n3 = y2021[(y2021['Need State']=='Need State 3')]
#y2021_n4 = y2021[(y2021['Need State']=='Need State 4')]
#y2021_n5 = y2021[(y2021['Need State']=='Need State 5')]
#y2021_n1.head()
