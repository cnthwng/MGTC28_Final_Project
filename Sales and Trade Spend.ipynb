# %%
pwd
# Out:
# 'C:\\Users\\cynth\\Downloads'

# %%
import pandas as pd
import seaborn as sns

# %%
df_TTSpend = pd.read_csv('kenvue_data\\Total Trade Spend.csv')

# %%
df_TSales = pd.read_csv('kenvue_data\\Total Sales - UTSC Lecture.csv')

# %%
df_TTSpend
# Out:
#      Fiscal Year  Fiscal Week  Need State 1  Need State 2  Need State 3  \
# 0           2021            1          5552         14264          1563
# 1           2021            2         18939         12329          8658
# 2           2021            3         11346          6351          4032
# 3           2021            4          4801         14715         13935
# 4           2021            5         17470         16092         13601
# ..           ...          ...           ...           ...           ...
# 144         2023           41          2918          2361         15546
# 145         2023           42         10743         15952          3993
# 146         2023           43          7823         19451         12462
# 147         2023           46         19575         14362         12145
# 148         2023           50         15705          4216          6644
#
#      Need State 4  Need State 5
# 0           18716          5075
# 1            8069         11307
# ...

# %%
df_TTSpend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Fiscal Year   149 non-null    int64
#  1   Fiscal Week   149 non-null    int64
#  2   Need State 1  149 non-null    int64
#  3   Need State 2  149 non-null    int64
#  4   Need State 3  149 non-null    int64
#  5   Need State 4  149 non-null    int64
#  6   Need State 5  149 non-null    int64
# dtypes: int64(7)
# memory usage: 8.3 KB

# %%
df_TTSpend.shape
# Out:
# (149, 7)

# %%
df_TSales.shape
# Out:
# (149, 7)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Plotting Weekly Sales Data

# %%
sns.lineplot(data=df_TSales, x='Fiscal Week', y='Need State 1', hue='Fiscal Year')
sns.lineplot(data=df_TSales, x='Fiscal Week', y='Need State 2', hue='Fiscal Year')
sns.lineplot(data=df_TSales, x='Fiscal Week', y='Need State 3', hue='Fiscal Year')
sns.lineplot(data=df_TSales, x='Fiscal Week', y='Need State 4', hue='Fiscal Year')
sns.lineplot(data=df_TSales, x='Fiscal Week', y='Need State 5', hue='Fiscal Year')
# Out:
# <Axes: xlabel='Fiscal Week', ylabel='Need State 1'>

# %% [markdown]
# ### Weekly Sales Trends for Each Need State

# %%
sns.lineplot(data=df_TSales, x='Fiscal Week', y='Need State 1', hue='Fiscal Year')
# Out:
# <Axes: xlabel='Fiscal Week', ylabel='Need State 1'>

# %%
sns.lineplot(data=df_TSales, x='Fiscal Week', y='Need State 2', hue='Fiscal Year')
# Out:
# <Axes: xlabel='Fiscal Week', ylabel='Need State 2'>

# %%
sns.lineplot(data=df_TSales, x='Fiscal Week', y='Need State 3', hue='Fiscal Year')
# Out:
# <Axes: xlabel='Fiscal Week', ylabel='Need State 3'>

# %%
sns.lineplot(data=df_TSales, x='Fiscal Week', y='Need State 4', hue='Fiscal Year')
# Out:
# <Axes: xlabel='Fiscal Week', ylabel='Need State 4'>

# %%
sns.lineplot(data=df_TSales, x='Fiscal Week', y='Need State 5', hue='Fiscal Year')
# Out:
# <Axes: xlabel='Fiscal Week', ylabel='Need State 5'>

# %% [markdown]
# ## 2023 Data

# %%
df_2023Sales = df_TSales[(df_TSales['Fiscal Year']==2023)]

# %%
df_2023Sales
# Out:
#      Fiscal Year  Fiscal Week  Need State 1  Need State 2  Need State 3  \
# 104         2023            1     230725.50     355815.00     323960.25
# 105         2023            2     402216.75     304145.25     309346.50
# 106         2023            3     227010.00     332245.50     340034.25
# 107         2023            4     660403.50     718207.50     435669.00
# 108         2023            5     216312.75     282531.75     320430.75
# 109         2023            6     470031.75     447660.75     511701.00
# 110         2023            7     970320.75     524059.50     313763.25
# 111         2023            8     675896.25     273267.75     193104.75
# 112         2023            9     490109.25     261685.50     145835.25
# 113         2023           10     491008.50     592058.25     138671.25
# 114         2023           11     308736.00     129294.00     163649.25
# 115         2023           12    1049037.75     621302.25     218181.75
# ...

# %%
sns.lineplot(data=df_2023Sales, x='Fiscal Week', y="Need State 1", color="black", ci=None)
sns.lineplot(data=df_2023Sales, x='Fiscal Week', y="Need State 2", color="red", ci=None)
sns.lineplot(data=df_2023Sales, x='Fiscal Week', y="Need State 3", color="green", ci=None)
sns.lineplot(data=df_2023Sales, x='Fiscal Week', y="Need State 4", color="blue", ci=None)
sns.lineplot(data=df_2023Sales, x='Fiscal Week', y="Need State 5", color="pink", ci=None).set(ylabel="Need State")
# Out:
# [Text(0, 0.5, 'Need State')]

# %%
import matplotlib.pyplot as plt

# %%
sns.lineplot(data=df_2023Sales, x='Fiscal Week', y="Need State 1", color="black", ci=None)
sns.lineplot(data=df_2023Sales, x='Fiscal Week', y="Need State 2", color="red", ci=None)
sns.lineplot(data=df_2023Sales, x='Fiscal Week', y="Need State 3", color="green", ci=None)
sns.lineplot(data=df_2023Sales, x='Fiscal Week', y="Need State 4", color="blue", ci=None)
sns.lineplot(data=df_2023Sales, x='Fiscal Week', y="Need State 5", color="pink", ci=None).set(ylabel="Need State")
plt.figure(figsize=(300,3))

# %% [markdown]
# #### Further Analysis can be conducted here for 2023 Data...

# %% [markdown]
# ## 2022 Data

# %%
df_2022Sales = df_TSales[(df_TSales['Fiscal Year']==2022)]

# %%
sns.lineplot(data=df_2022Sales, x='Fiscal Week', y="Need State 1", color="black", ci=None)
sns.lineplot(data=df_2022Sales, x='Fiscal Week', y="Need State 2", color="red", ci=None)
sns.lineplot(data=df_2022Sales, x='Fiscal Week', y="Need State 3", color="green", ci=None)
sns.lineplot(data=df_2022Sales, x='Fiscal Week', y="Need State 4", color="blue", ci=None)
sns.lineplot(data=df_2022Sales, x='Fiscal Week', y="Need State 5", color="pink", ci=None).set(ylabel="Need State")
# Out:
# [Text(0, 0.5, 'Need State')]

# %% [markdown]
# ## 2021 Data

# %%
df_2021Sales = df_TSales[(df_TSales['Fiscal Year']==2021)]

# %%
sns.lineplot(data=df_2021Sales, x='Fiscal Week', y="Need State 1", color="black", ci=None)
sns.lineplot(data=df_2021Sales, x='Fiscal Week', y="Need State 2", color="red", ci=None)
sns.lineplot(data=df_2021Sales, x='Fiscal Week', y="Need State 3", color="green", ci=None)
sns.lineplot(data=df_2021Sales, x='Fiscal Week', y="Need State 4", color="blue", ci=None)
sns.lineplot(data=df_2021Sales, x='Fiscal Week', y="Need State 5", color="pink", ci=None).set(ylabel="Need State")
# Out:
# [Text(0, 0.5, 'Need State')]

# %% [markdown]
# # Plotting Trade Spend Data

# %%
sns.lineplot(data=df_TTSpend, x='Fiscal Week', y='Need State 1', hue='Fiscal Year')
# Out:
# <Axes: xlabel='Fiscal Week', ylabel='Need State 1'>

# %%
sns.lineplot(data=df_TTSpend, x='Fiscal Week', y='Need State 2', hue='Fiscal Year')
# Out:
# <Axes: xlabel='Fiscal Week', ylabel='Need State 2'>

# %%
sns.lineplot(data=df_TTSpend, x='Fiscal Week', y='Need State 3', hue='Fiscal Year')
# Out:
# <Axes: xlabel='Fiscal Week', ylabel='Need State 3'>

# %%
sns.lineplot(data=df_TTSpend, x='Fiscal Week', y='Need State 4', hue='Fiscal Year')
# Out:
# <Axes: xlabel='Fiscal Week', ylabel='Need State 4'>

# %%
sns.lineplot(data=df_TTSpend, x='Fiscal Week', y='Need State 5', hue='Fiscal Year')
# Out:
# <Axes: xlabel='Fiscal Week', ylabel='Need State 5'>

# %% [markdown]
# ## 2023 Data

# %%
df_2023Spend = df_TTSpend[(df_TTSpend['Fiscal Year']==2023)]

# %%
sns.lineplot(data=df_2023Spend, x='Fiscal Week', y="Need State 1", color="black", ci=None)
sns.lineplot(data=df_2023Spend, x='Fiscal Week', y="Need State 2", color="red", ci=None)
sns.lineplot(data=df_2023Spend, x='Fiscal Week', y="Need State 3", color="green", ci=None)
sns.lineplot(data=df_2023Spend, x='Fiscal Week', y="Need State 4", color="blue", ci=None)
sns.lineplot(data=df_2023Spend, x='Fiscal Week', y="Need State 5", color="pink", ci=None).set(ylabel="Need State")
# Out:
# [Text(0, 0.5, 'Need State')]

# %% [markdown]
# ## 2022 Data

# %%
df_2022Spend = df_TTSpend[(df_TTSpend['Fiscal Year']==2022)]

# %%
sns.lineplot(data=df_2022Spend, x='Fiscal Week', y="Need State 1", color="black", ci=None)
sns.lineplot(data=df_2022Spend, x='Fiscal Week', y="Need State 2", color="red", ci=None)
sns.lineplot(data=df_2022Spend, x='Fiscal Week', y="Need State 3", color="green", ci=None)
sns.lineplot(data=df_2022Spend, x='Fiscal Week', y="Need State 4", color="blue", ci=None)
sns.lineplot(data=df_2022Spend, x='Fiscal Week', y="Need State 5", color="pink", ci=None).set(ylabel="Need State")
# Out:
# [Text(0, 0.5, 'Need State')]

# %% [markdown]
# ## Creating a df for Sales & Trade Spend for Each Quarter

# %%
# Group by Quarter for Sales

Q1 = df_TSales[(df_TSales['Fiscal Week']<=13)]
Q2 = df_TSales[(df_TSales['Fiscal Week']>13) & (df_TSales['Fiscal Week']<=26)]
Q3 = df_TSales[(df_TSales['Fiscal Week']>26) & (df_TSales['Fiscal Week']<=39)]
Q4 = df_TSales[(df_TSales['Fiscal Week']>39)]

# %%
Q1 = Q1.groupby('Fiscal Year').sum().reset_index()
Q2 = Q2.groupby('Fiscal Year').sum().reset_index()
Q3 = Q3.groupby('Fiscal Year').sum().reset_index()
Q4 = Q4.groupby('Fiscal Year').sum().reset_index()

# %%
Q1 = df_TTSpend[(df_TSales['Fiscal Week']<=13)]
Q2 = df_TTSpend[(df_TSales['Fiscal Week']>13) & (df_TSales['Fiscal Week']<=26)]
Q3 = df_TTSpend[(df_TSales['Fiscal Week']>26) & (df_TSales['Fiscal Week']<=39)]
Q4 = df_TTSpend[(df_TSales['Fiscal Week']>39)]

# %%
Q1 = Q1.groupby('Fiscal Year').sum().reset_index()
Q2 = Q2.groupby('Fiscal Year').sum().reset_index()
Q3 = Q3.groupby('Fiscal Year').sum().reset_index()
Q4 = Q4.groupby('Fiscal Year').sum().reset_index()

# %%
new = [Q1, Q2, Q3, Q4]

# %%
new_sheet = pd.concat(new)
new_sheet = new_sheet.sort_values(by=['Fiscal Year'])
new_sheet
# Out:
#    Fiscal Year  Fiscal Week  Need State 1  Need State 2  Need State 3  \
# 0         2021           91        176299        149619        118647
# 0         2021          260        133661        149955        127221
# 0         2021          429        130138        139858        154208
# 0         2021          598        158874        136533        153477
# 1         2022           91        123633        100625        157117
# 1         2022          260        133687        122079        117478
# 1         2022          429        143070        110173        109729
# 1         2022          598        146282        140242        157094
# 2         2023           91         97734        110885        146637
# 2         2023          260        141776        128459        159541
# 2         2023          429        133279        133593        131917
# 2         2023          262         76529         63150         63105
#
#    Need State 4  Need State 5
# ...

# %% [markdown]
# ## Trade Spend Per Quarter & Need State (Data Export)

# %%
new_sheet.to_csv('tradespend.csv', index=False, encoding='utf-8')

# %%
Q1
# Out:
#    Fiscal Year  Fiscal Week  Need State 1  Need State 2  Need State 3  \
# 0         2021           91        176299        149619        118647
# 1         2022           91        123633        100625        157117
# 2         2023           91         97734        110885        146637
#
#    Need State 4  Need State 5
# 0        136373        120137
# 1        143979        165146
# 2        132036        130073

# %%
Annual_Spend = df_TTSpend.groupby('Fiscal Year').sum().reset_index()
Annual_Spend = Annual_Spend.drop('Fiscal Week', axis=1)
Annual_Spend
# Out:
#    Fiscal Year  Need State 1  Need State 2  Need State 3  Need State 4  \
# 0         2021        598972        575965        553553        487762
# 1         2022        546672        473119        541418        517459
# 2         2023        449318        436087        501200        438457
#
#    Need State 5
# 0        540220
# 1        592511
# 2        433446

# %%
Annual_Sales = df_TSales.groupby('Fiscal Year').sum().reset_index()
Annual_Sales = Annual_Sales.drop('Fiscal Week', axis=1)
Annual_Sales
# Out:
#    Fiscal Year  Need State 1  Need State 2  Need State 3  Need State 4  \
# 0         2021   29739995.25   19568683.50   19101012.00    22267800.0
# 1         2022   31246989.75   20814321.75   19183299.75    21826323.0
# 2         2023   25045303.50   17546953.50   13766230.50    17122915.5
#
#    Need State 5
# 0   26985564.75
# 1   29768792.25
# 2   24757329.00

# %%
Y_2021 = [Q1, Q2, Q3, Q4]

# %%
Q1.to_csv('test1.csv', index=False, encoding='utf-8')

# %%
Q2.to_csv('test2.csv', index=False, encoding='utf-8')
Q3.to_csv('test3.csv', index=False, encoding='utf-8')

# %%
Q4.to_csv('test4.csv', index=False, encoding='utf-8')
